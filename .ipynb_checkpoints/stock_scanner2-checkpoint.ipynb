# %%
import yfinance as yf
import pandas as pd
from datetime import datetime

# Function to get stock data
def get_stock_data(stock_symbol, period):
    stock_data = yf.Ticker(stock_symbol)
    hist = stock_data.history(period=period)
    return hist

# Function to analyze stocks for lifetime highs, pullbacks, and price appreciation
def analyze_stocks(stock_symbols, analysis_period='10y', appreciation_threshold=5):  # Adjusted to 5%
    summary = {
        'Total Opportunities': 0,
        'Annual Opportunities': 0.0,
        'Success Rate': 0.0,
    }
    detailed_results = []
    
    for stock in stock_symbols:
        print(f"Analyzing {stock}...")
        hist = get_stock_data(stock, analysis_period)

        if len(hist) == 0:
            print(f"No data available for {stock}.")
            continue

        # Get the lifetime high and its date
        lifetime_high = hist['Close'].max()
        high_date = hist['Close'].idxmax().date()
        
        # Identify potential support and price drop after the high
        price_after_high = hist[hist.index > pd.Timestamp(high_date)]['Close']
        if len(price_after_high) == 0:
            continue
        
        # Check for a pullback of at least 10% below the lifetime high
        pullback_threshold = lifetime_high * 0.90
        has_pullback = price_after_high.min() < pullback_threshold
        
        # Current price to compare for appreciation
        current_price = hist['Close'].iloc[-1]
        
        # Log the current and lifetime high for debugging
        print(f"Lifelong High: {lifetime_high}, Current Price: {current_price}")

        # Check for price appreciation after a pullback
        if has_pullback and current_price >= lifetime_high * (1 + appreciation_threshold / 100):
            price_appreciation = ((current_price - lifetime_high) / lifetime_high) * 100
            detailed_results.append({
                'Ticker': stock,
                'Lifetime High': lifetime_high,
                'Date of High': high_date,
                'Price After High': current_price,
                'Price Appreciation (%)': price_appreciation
            })
            summary['Total Opportunities'] += 1

    # Calculate annual opportunities and success rate
    if detailed_results:
        summary['Annual Opportunities'] = summary['Total Opportunities'] / (datetime.now().year - (datetime.now().year - 10))
        summary['Success Rate'] = (summary['Total Opportunities'] / len(stock_symbols)) * 100

    return summary, detailed_results

# List of stock symbols to analyze
stock_symbols = ['AAPL', 'TSLA', 'GOOGL', 'AMZN', 'MSFT', 'NFLX']  # Add your own list of stocks

# Run the analysis
summary, detailed_results = analyze_stocks(stock_symbols, analysis_period='10y', appreciation_threshold=5)

# Print summary
print("\nSummary of Results:")
print(f"Total Opportunities: {summary['Total Opportunities']}")
print(f"Annual Opportunities: {summary['Annual Opportunities']:.2f}")
print(f"Success Rate: {summary['Success Rate']:.2f}%")

# Print detailed results
print("\nDetailed Results:")
if detailed_results:
    for result in detailed_results:
        print(result)
else:
    print("No detailed results available.")
# Out:
# Analyzing AAPL...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\arrays\datetimelike.py:536, in DatetimeLikeArrayMixin._validate_comparison_value(self, other)
#     535 try:
# --> 536     self._check_compatible_with(other)
#     537 except (TypeError, IncompatibleFrequency) as err:
#     538     # e.g. tzawareness mismatch
#
# File ~\anaconda3\Lib\site-packages\pandas\core\arrays\datetimes.py:540, in DatetimeArray._check_compatible_with(self, other)
#     539     return
# --> 540 self._assert_tzawareness_compat(other)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\arrays\datetimes.py:786, in DatetimeArray._assert_tzawareness_compat(self, other)
#     785 elif other_tz is None:
# --> 786     raise TypeError(
#     787         "Cannot compare tz-naive and tz-aware datetime-like objects"
#     788     )
#
# TypeError: Cannot compare tz-naive and tz-aware datetime-like objects
#
# The above exception was the direct cause of the following exception:
#
# InvalidComparison                         Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\arrays\datetimelike.py:983, in DatetimeLikeArrayMixin._cmp_method(self, other, op)
#     982 try:
# --> 983     other = self._validate_comparison_value(other)
#     984 except InvalidComparison:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\arrays\datetimelike.py:539, in DatetimeLikeArrayMixin._validate_comparison_value(self, other)
#     537     except (TypeError, IncompatibleFrequency) as err:
#     538         # e.g. tzawareness mismatch
# --> 539         raise InvalidComparison(other) from err
#     541 elif not is_list_like(other):
#
# InvalidComparison: 2024-07-16 00:00:00
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 70
#      67 stock_symbols = ['AAPL', 'TSLA', 'GOOGL', 'AMZN', 'MSFT', 'NFLX']  # Add your own list of stocks
#      69 # Run the analysis
# ---> 70 summary, detailed_results = analyze_stocks(stock_symbols, analysis_period='10y', appreciation_threshold=5)
#      72 # Print summary
#      73 print("\nSummary of Results:")
#
# Cell In[2], line 33, in analyze_stocks(stock_symbols, analysis_period, appreciation_threshold)
#      30 high_date = hist['Close'].idxmax().date()
#      32 # Identify potential support and price drop after the high
# ---> 33 price_after_high = hist[hist.index > pd.Timestamp(high_date)]['Close']
#      34 if len(price_after_high) == 0:
#      35     continue
#
# File ~\anaconda3\Lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\arraylike.py:56, in OpsMixin.__gt__(self, other)
#      54 @unpack_zerodim_and_defer("__gt__")
#      55 def __gt__(self, other):
# ---> 56     return self._cmp_method(other, operator.gt)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:7197, in Index._cmp_method(self, other, op)
#    7194     result = op(self._values, other)
#    7196 elif isinstance(self._values, ExtensionArray):
# -> 7197     result = op(self._values, other)
#    7199 elif is_object_dtype(self.dtype) and not isinstance(self, ABCMultiIndex):
#    7200     # don't pass MultiIndex
#    7201     result = ops.comp_method_OBJECT_ARRAY(op, self._values, other)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\arraylike.py:56, in OpsMixin.__gt__(self, other)
#      54 @unpack_zerodim_and_defer("__gt__")
#      55 def __gt__(self, other):
# ---> 56     return self._cmp_method(other, operator.gt)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\arrays\datetimelike.py:985, in DatetimeLikeArrayMixin._cmp_method(self, other, op)
#     983     other = self._validate_comparison_value(other)
#     984 except InvalidComparison:
# --> 985     return invalid_comparison(self, other, op)
#     987 dtype = getattr(other, "dtype", None)
#     988 if is_object_dtype(dtype):
#     989     # We have to use comp_method_OBJECT_ARRAY instead of numpy
#     990     #  comparison otherwise it would raise when comparing to None
#
# File ~\anaconda3\Lib\site-packages\pandas\core\ops\invalid.py:40, in invalid_comparison(left, right, op)
#      38 else:
#      39     typ = type(right).__name__
# ---> 40     raise TypeError(f"Invalid comparison between dtype={left.dtype} and {typ}")
#      41 return res_values
#
# TypeError: Invalid comparison between dtype=datetime64[ns, America/New_York] and Timestamp
